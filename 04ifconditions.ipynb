# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshtrikal17/PythonDBWebDSAIML-January2026/blob/main/04ifconditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input('Enter name : ')
marks=int(input('Enter marks : '))
if marks>=35:
  print('Congratulations')
  print(f'{name} you are pass')
else:
  print('Sorry')
  print(f'{name} you are fail')
# Out:
# Enter name : Rushikesh
# Enter marks : 45
# Congratulations
# Rushikesh you are pass

# %% [markdown]
# find out if the number is odd or even

# %%
n=int(input('Enter a number : '))
if n%2==0:
  print('number is even')
else:
  print('number is odd')
# Out:
# Enter a number : 3
# number is odd

# %%
n=int(input('Enter a number : '))
if n==0:
  print(f'{n} is a neutral number')
else:
  if n>0:
    print('number is positive')
  else:
    print('number is negative')
# Out:
# Enter a number : 0
# 0 is a neutral number

# %%
password=input('Enter your password : ')
if password=='rushikesh@123':
  print('welcome to python')
else:
  print('sorry password incorrect')
# Out:
# Enter your password : rushikesh@123
# welcome to python

# %%
custnm=input('Enter customer name : ')
amount=float(input('Enter purchase amount : '))
if amount>20000:
  print('13% discount applied')
  discount=amount*13/100
else:
  print('9% discount applied')
  discount=amount*9/100

netbill=amount-discount
print(f'Customer Name : {custnm}')
print(f'Amount : {amount}')
print(f'Discount : {discount}')
print(f'Net Bill : {netbill}')
# Out:
# Enter customer name : Pallavi
# Enter purchase amount : 25000
# 13% discount applied
# Customer Name : Pallavi
# Amount : 25000.0
# Discount : 3250.0
# Net Bill : 21750.0

# %%
perc=float(input('Enter percentage : '))
if perc>=75:
  print('passed in distinction')
elif perc>=60 and perc<75:
  print('passed in first class')
elif perc>=35 and perc<60:
  print('student passed')
else:
  print('student failed to clear the exam')
# Out:
# Enter percentage : 61
# passed in first class
