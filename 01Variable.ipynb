# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshtrikal17/PythonDBWebDSAIML-January2026/blob/main/01Variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=35
b=13
c=a+b
print(f"sum of {a} and {b} is {c}")
# Out:
# sum of 35 and 13 is 48

# %%
x=5
print(f"square of {x} is {x*x}")
# Out:
# square of 5 is 25

# %%
name="Rushikesh"
print(f"Welcome {name} to the exciting world of python")
# Out:
# Welcome Rushikesh to the exciting world of python

# %%
x=50.45
y=12.2
z=x+y
print(f"sum is {z}")
print(type(z))
# Out:
# sum is 62.650000000000006
# <class 'float'>
