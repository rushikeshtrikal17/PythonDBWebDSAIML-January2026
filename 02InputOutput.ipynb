# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshtrikal17/PythonDBWebDSAIML-January2026/blob/main/02InputOutput.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  INPUT OUTPUT IN PYTHON

# %%
nm=input('Enter your name ')
# Out:
# Enter your name Rushikesh

# %%
print(f'user name is {nm}')
# Out:
# user name is Rushikesh

# %%
n=int(input('Enter a number '))
sq=n*n
print(f"square of {n} is {sq}")
# Out:
# Enter a number 25
# square of 25 is 625

# %%
x=float(input('Enter first number '))
y=float(input('Enter second number '))
z=x+y
print(f"sum of {x} and {y} is {z}")
# Out:
# Enter first number 2
# Enter second number 4
# sum of 2.0 and 4.0 is 6.0

# %%
custnm=input('Enter customer name ')
amount=float(input('Enter purchase amount '))
discount=amount*10/100
net=amount-discount
print(f'Customer Name : {custnm}')
print(f'Purchase amount : {amount}')
print(f'Discount : {discount}')
print(f'Net Bill : {net}')
# Out:
# Enter customer name Pallavi
# Enter purchase amount 4500
# Customer Name : Pallavi
# Purchase amount : 4500.0
# Discount : 450.0
# Net Bill : 4050.0
